# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Administrator\Desktop\airquality.csv")

# %%
data
# Out:
#               Timestamp   PM2.5
# 0      01-01-2018 00:00   90.19
# 1      01-01-2018 01:00   86.98
# 2      01-01-2018 02:00   86.06
# 3      01-01-2018 03:00   94.04
# 4      01-01-2018 04:00  108.78
# ...                 ...     ...
# 31856  31-12-2021 19:00   72.25
# 31857  31-12-2021 20:00   71.56
# 31858  31-12-2021 21:00   70.27
# 31859  31-12-2021 22:00   66.78
# 31860  31-12-2021 23:00   61.29
#
# [31861 rows x 2 columns]

# %%
data.head(50)
# Out:
#            Timestamp   PM2.5
# 0   01-01-2018 00:00   90.19
# 1   01-01-2018 01:00   86.98
# 2   01-01-2018 02:00   86.06
# 3   01-01-2018 03:00   94.04
# 4   01-01-2018 04:00  108.78
# 5   01-01-2018 05:00  117.86
# 6   01-06-2018 17:00  150.89
# 7   11-07-2018 21:00  245.63
# 8   11-08-2018 00:00  175.19
# 9   01-01-2018 09:00   92.45
# 10  01-01-2018 10:00   86.30
# 11  01-01-2018 11:00   81.89
# 12  01-01-2018 12:00   85.25
# 13  01-01-2018 13:00   90.22
# 14  01-01-2018 14:00   96.85
# 15  01-01-2018 15:00  115.41
# 16  01-01-2018 16:00  121.05
# 17  01-01-2018 17:00  116.76
# 18  01-01-2018 18:00  111.28
# 19  01-01-2018 19:00  104.21
# 20  01-01-2018 20:00   90.63
# 21  01-01-2018 21:00   83.88
# 22  01-01-2018 22:00   78.86
# 23  01-01-2018 23:00   76.20
# 24  02-01-2018 00:00   75.76
# 25  02-01-2018 01:00   76.48
# 26  02-01-2018 02:00   80.66
# 27  02-01-2018 03:00   84.68
# 28  02-01-2018 04:00   92.51
# 29  02-01-2018 05:00   98.93
# 30  06-01-2018 16:00  146.88
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.isnull().sum()
# Out:
# Timestamp    0
# PM2.5        0
# dtype: int64

# %%
data.size
# Out:
# 63722

# %%
data.count
# Out:
# <bound method DataFrame.count of               Timestamp   PM2.5
# 0      01-01-2018 00:00   90.19
# 1      01-01-2018 01:00   86.98
# 2      01-01-2018 02:00   86.06
# 3      01-01-2018 03:00   94.04
# 4      01-01-2018 04:00  108.78
# ...                 ...     ...
# 31856  31-12-2021 19:00   72.25
# 31857  31-12-2021 20:00   71.56
# 31858  31-12-2021 21:00   70.27
# 31859  31-12-2021 22:00   66.78
# 31860  31-12-2021 23:00   61.29
#
# [31861 rows x 2 columns]>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31861 entries, 0 to 31860
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  31861 non-null  object
#  1   PM2.5      31861 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 498.0+ KB

# %%
data.shape
# Out:
# (31861, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31861 entries, 0 to 31860
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  31861 non-null  object
#  1   PM2.5      31861 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 498.0+ KB

# %%
data['Timestamp'] = pd.to_datetime(data['Timestamp'])

# %%
data.head()
# Out:
#             Timestamp   PM2.5
# 0 2018-01-01 00:00:00   90.19
# 1 2018-01-01 01:00:00   86.98
# 2 2018-01-01 02:00:00   86.06
# 3 2018-01-01 03:00:00   94.04
# 4 2018-01-01 04:00:00  108.78

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31861 entries, 0 to 31860
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  31861 non-null  datetime64[ns]
#  1   PM2.5      31861 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 498.0 KB

# %%
data.rename(columns = {'Timestamp' : 'Datetime'}, inplace = True )

# %%
data.head(2)
# Out:
#              Datetime  PM2.5
# 0 2018-01-01 00:00:00  90.19
# 1 2018-01-01 01:00:00  86.98

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31861 entries, 0 to 31860
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datetime  31861 non-null  datetime64[ns]
#  1   PM2.5     31861 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 498.0 KB

# %%
data.head()
# Out:
#              Datetime   PM2.5
# 0 2018-01-01 00:00:00   90.19
# 1 2018-01-01 01:00:00   86.98
# 2 2018-01-01 02:00:00   86.06
# 3 2018-01-01 03:00:00   94.04
# 4 2018-01-01 04:00:00  108.78

# %%
data['year'] = data.Datetime.dt.year

# %%
data.head()
# Out:
#              Datetime   PM2.5  year
# 0 2018-01-01 00:00:00   90.19  2018
# 1 2018-01-01 01:00:00   86.98  2018
# 2 2018-01-01 02:00:00   86.06  2018
# 3 2018-01-01 03:00:00   94.04  2018
# 4 2018-01-01 04:00:00  108.78  2018

# %%
data.groupby('year')['PM2.5'].mean()
# Out:
# year
# 2018    54.468449
# 2019    49.511273
# 2020    42.386302
# 2021    44.850633
# Name: PM2.5, dtype: float64

# %%
year_avg = data.groupby('year')['PM2.5'].mean()

# %%
year_avg
# Out:
# year
# 2018    54.468449
# 2019    49.511273
# 2020    42.386302
# 2021    44.850633
# Name: PM2.5, dtype: float64

# %%
year_avg.plot(kind = 'line', color = 'red')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
data.head(2)
# Out:
#              Datetime  PM2.5  year
# 0 2018-01-01 00:00:00  90.19  2018
# 1 2018-01-01 01:00:00  86.98  2018

# %%
data['month'] = data.Datetime.dt.month

# %%
data.head()
# Out:
#              Datetime   PM2.5  year  month
# 0 2018-01-01 00:00:00   90.19  2018      1
# 1 2018-01-01 01:00:00   86.98  2018      1
# 2 2018-01-01 02:00:00   86.06  2018      1
# 3 2018-01-01 03:00:00   94.04  2018      1
# 4 2018-01-01 04:00:00  108.78  2018      1

# %%
data.tail(50)
# Out:
#                  Datetime  PM2.5  year  month
# 31811 2021-12-29 20:00:00  62.86  2021     12
# 31812 2021-12-29 21:00:00  61.65  2021     12
# 31813 2021-12-29 22:00:00  56.43  2021     12
# 31814 2021-12-29 23:00:00  54.67  2021     12
# 31815 2021-12-30 00:00:00  54.47  2021     12
# 31816 2021-12-30 01:00:00  52.28  2021     12
# 31817 2021-12-30 02:00:00  52.58  2021     12
# 31818 2021-12-30 03:00:00  54.06  2021     12
# 31819 2021-12-30 04:00:00  54.57  2021     12
# 31820 2021-12-30 05:00:00  64.86  2021     12
# 31821 2021-12-30 06:00:00  64.94  2021     12
# 31822 2021-12-30 08:00:00  51.32  2021     12
# 31823 2021-12-30 09:00:00  50.29  2021     12
# 31824 2021-12-30 10:00:00  43.00  2021     12
# 31825 2021-12-30 11:00:00  42.55  2021     12
# 31826 2021-12-30 12:00:00  42.13  2021     12
# 31827 2021-12-30 13:00:00  43.92  2021     12
# 31828 2021-12-30 14:00:00  46.49  2021     12
# 31829 2021-12-30 15:00:00  54.56  2021     12
# ...

# %%
data.groupby('month')['PM2.5'].mean()
# Out:
# month
# 1     65.829067
# 2     55.264291
# 3     49.666820
# 4     43.625814
# 5     39.816285
# 6     35.817151
# 7     31.884161
# 8     31.928300
# 9     36.324103
# 10    51.514817
# 11    60.017498
# 12    64.614865
# Name: PM2.5, dtype: float64

# %%
month_avg = data.groupby('month')['PM2.5'].mean()

# %%
month_avg
# Out:
# month
# 1     65.829067
# 2     55.264291
# 3     49.666820
# 4     43.625814
# 5     39.816285
# 6     35.817151
# 7     31.884161
# 8     31.928300
# 9     36.324103
# 10    51.514817
# 11    60.017498
# 12    64.614865
# Name: PM2.5, dtype: float64

# %%
month_avg.plot(kind = 'area',figsize = (12,5) , style = "*",color = 'green')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
data['hour'] = data.Datetime.dt.hour

# %%
data.head(2)
# Out:
#              Datetime  PM2.5  year  month  hour
# 0 2018-01-01 00:00:00  90.19  2018      1     0
# 1 2018-01-01 01:00:00  86.98  2018      1     1

# %%
hour_mean = data.groupby('hour')['PM2.5'].mean()

# %%
hour_mean
# Out:
# hour
# 0     47.068769
# 1     46.403946
# 2     46.952281
# 3     49.150798
# 4     51.296204
# 5     51.908798
# 6     49.907545
# 7     47.518554
# 8     44.996127
# 9     42.681736
# 10    40.931766
# 11    39.393820
# 12    38.789992
# 13    39.323346
# 14    42.638162
# 15    47.500464
# 16    51.244844
# 17    53.669757
# 18    54.317363
# 19    54.120371
# 20    52.784130
# 21    51.383525
# 22    49.940615
# 23    48.538064
# Name: PM2.5, dtype: float64

# %%
hour_mean.plot(kind = 'line', color = 'orange');

# %%
hour_mean.plot(kind = 'bar', color = 'orange');

# %%
data.head(50)
# Out:
#               Datetime   PM2.5  year  month  hour
# 0  2018-01-01 00:00:00   90.19  2018      1     0
# 1  2018-01-01 01:00:00   86.98  2018      1     1
# 2  2018-01-01 02:00:00   86.06  2018      1     2
# 3  2018-01-01 03:00:00   94.04  2018      1     3
# 4  2018-01-01 04:00:00  108.78  2018      1     4
# 5  2018-01-01 05:00:00  117.86  2018      1     5
# 6  2018-01-06 17:00:00  150.89  2018      1    17
# 7  2018-11-07 21:00:00  245.63  2018     11    21
# 8  2018-11-08 00:00:00  175.19  2018     11     0
# 9  2018-01-01 09:00:00   92.45  2018      1     9
# 10 2018-01-01 10:00:00   86.30  2018      1    10
# 11 2018-01-01 11:00:00   81.89  2018      1    11
# 12 2018-01-01 12:00:00   85.25  2018      1    12
# 13 2018-01-01 13:00:00   90.22  2018      1    13
# 14 2018-01-01 14:00:00   96.85  2018      1    14
# 15 2018-01-01 15:00:00  115.41  2018      1    15
# 16 2018-01-01 16:00:00  121.05  2018      1    16
# 17 2018-01-01 17:00:00  116.76  2018      1    17
# ...

# %%
data[(data['PM2.5'] >= 150.5) & (data['PM2.5'] <= 250.4)]
# Out:
#                  Datetime   PM2.5  year  month  hour
# 6     2018-01-06 17:00:00  150.89  2018      1    17
# 7     2018-11-07 21:00:00  245.63  2018     11    21
# 8     2018-11-08 00:00:00  175.19  2018     11     0
# 31    2018-11-07 22:00:00  232.03  2018     11    22
# 32    2018-11-08 01:00:00  169.15  2018     11     1
# 55    2018-11-07 20:00:00  223.21  2018     11    20
# 56    2018-11-08 03:00:00  160.34  2018     11     3
# 79    2018-11-07 18:00:00  212.56  2018     11    18
# 103   2018-11-07 19:00:00  207.41  2018     11    19
# 126   2018-11-07 17:00:00  183.19  2018     11    17
# 143   2018-11-07 23:00:00  173.67  2018     11    23
# 284   2018-01-13 16:00:00  165.45  2018      1    16
# 285   2018-01-13 17:00:00  177.58  2018      1    17
# 286   2018-01-13 18:00:00  175.32  2018      1    18
# 287   2018-01-13 19:00:00  166.60  2018      1    19
# 7578  2019-02-01 17:00:00  165.82  2019      2    17
# 7579  2019-02-01 18:00:00  157.99  2019      2    18
# ...

# %%
air_unhealthy = data[(data['PM2.5'] >= 150.5) & (data['PM2.5'] <= 250.4)]

# %%
air_unhealthy.plot(kind = 'bar');

# %%
air_unhealthy.value_counts('month')
# Out:
# month
# 11    16
# 1      5
# 10     5
# 2      2
# dtype: int64

# %%
data[(data['PM2.5'] == 0 ) | (data['PM2.5'] <= 12.0)]
# Out:
#                  Datetime  PM2.5  year  month  hour
# 11423 2019-06-22 08:00:00  11.53  2019      6     8
# 11424 2019-06-22 09:00:00  10.31  2019      6     9
# 11471 2019-06-24 08:00:00  10.98  2019      6     8
# 11472 2019-06-24 09:00:00  11.64  2019      6     9
# 11535 2019-06-27 00:00:00  11.77  2019      6     0
# 11874 2019-07-13 09:00:00   7.02  2019      7     9
# 11875 2019-07-13 10:00:00   7.48  2019      7    10
# 11876 2019-07-13 11:00:00   7.61  2019      7    11
# 11879 2019-07-13 14:00:00  11.08  2019      7    14
# 11880 2019-07-13 15:00:00  10.21  2019      7    15
# 11881 2019-07-13 16:00:00  11.76  2019      7    16
# 12530 2019-08-25 03:00:00  11.71  2019      8     3
# 12542 2019-08-25 15:00:00  11.25  2019      8    15
# 12545 2019-08-25 18:00:00  10.68  2019      8    18
# 12626 2019-08-30 14:00:00  11.02  2019      8    14
# 12627 2019-08-30 15:00:00   9.93  2019      8    15
# 12628 2019-08-30 16:00:00   9.55  2019      8    16
# ...

# %%
 y = data[(data['PM2.5']) <= 12.0]

# %%
y.value_counts('month')
# Out:
# month
# 8    33
# 7     6
# 6     5
# 1     3
# 4     3
# 5     2
# dtype: int64

# %%
data[(data['year'] == 2018) & (data['PM2.5'] >= 12.1) & (data['PM2.5'] <= 35.4)]
# Out:
#                  Datetime  PM2.5  year  month  hour
# 1820  2018-01-04 04:00:00  33.34  2018      1     4
# 2038  2018-12-04 00:00:00  35.39  2018     12     0
# 2215  2018-04-19 13:00:00  28.90  2018      4    13
# 2306  2018-04-23 09:00:00  34.83  2018      4     9
# 2307  2018-04-23 11:00:00  33.50  2018      4    11
# ...                   ...    ...   ...    ...   ...
# 9981  2018-06-28 06:00:00  19.75  2018      6     6
# 9982  2018-07-17 07:00:00  19.27  2018      7     7
# 9983  2018-07-16 08:00:00  18.96  2018      7     8
# 10004 2018-08-25 06:00:00  17.45  2018      8     6
# 10006 2018-07-17 08:00:00  18.77  2018      7     8
#
# [2239 rows x 5 columns]

# %%
 z = data[(data['year'] == 2018) & (data['PM2.5'] >= 12.1) & (data['PM2.5'] <= 35.4)]

# %%
z.value_counts('month')
# Out:
# month
# 7     516
# 8     513
# 9     311
# 6     307
# 10     85
# 11     82
# 3      79
# 12     73
# 2      71
# 1      68
# 5      68
# 4      66
# dtype: int64

# %%
data.head()
# Out:
#              Datetime   PM2.5  year  month  hour
# 0 2018-01-01 00:00:00   90.19  2018      1     0
# 1 2018-01-01 01:00:00   86.98  2018      1     1
# 2 2018-01-01 02:00:00   86.06  2018      1     2
# 3 2018-01-01 03:00:00   94.04  2018      1     3
# 4 2018-01-01 04:00:00  108.78  2018      1     4

# %%
data.head(50)
# Out:
#               Datetime   PM2.5  year  month  hour
# 0  2018-01-01 00:00:00   90.19  2018      1     0
# 1  2018-01-01 01:00:00   86.98  2018      1     1
# 2  2018-01-01 02:00:00   86.06  2018      1     2
# 3  2018-01-01 03:00:00   94.04  2018      1     3
# 4  2018-01-01 04:00:00  108.78  2018      1     4
# 5  2018-01-01 05:00:00  117.86  2018      1     5
# 6  2018-01-06 17:00:00  150.89  2018      1    17
# 7  2018-11-07 21:00:00  245.63  2018     11    21
# 8  2018-11-08 00:00:00  175.19  2018     11     0
# 9  2018-01-01 09:00:00   92.45  2018      1     9
# 10 2018-01-01 10:00:00   86.30  2018      1    10
# 11 2018-01-01 11:00:00   81.89  2018      1    11
# 12 2018-01-01 12:00:00   85.25  2018      1    12
# 13 2018-01-01 13:00:00   90.22  2018      1    13
# 14 2018-01-01 14:00:00   96.85  2018      1    14
# 15 2018-01-01 15:00:00  115.41  2018      1    15
# 16 2018-01-01 16:00:00  121.05  2018      1    16
# 17 2018-01-01 17:00:00  116.76  2018      1    17
# ...

# %%
data[data['month'] == 1]['PM2.5'].mean()   #  unhealthy, the level of  air quality in january month
# Out:
# 65.82906685236769

# %%
data[data['month'] == 7]['PM2.5'].mean()  # the level of air quality in july is moderate
# Out:
# 31.88416146645866
